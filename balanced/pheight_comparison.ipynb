# %%
import numpy as np
import xarray as xar
import matplotlib.pyplot as plt

# %%
cyclone_balanced = xar.open_dataset('cyclone_balanced.nc')
cyclone_not = xar.open_dataset('cyclone_not.nc')

pheight_bal = cyclone_balanced.pheight[:, 300, 300]
pheight_not = cyclone_not.pheight[:, 300, 300]

# %%
pheight_bal
# Out:
# <xarray.DataArray 'pheight' (t: 500)>
# [500 values with dtype=float64]
# Coordinates:
#     sim_time      (t) float64 ...
#     world_time    (t) float64 ...
#     wall_time     (t) float64 ...
#     timestep      (t) float64 ...
#     iteration     (t) int64 ...
#     write_number  (t) int64 ...
#     x             float64 0.08594
#     y             float64 0.08594
#   * t             (t) float64 0.0 0.11 0.2 0.3 0.4 ... 49.5 49.6 49.7 49.8 49.9

# %%
plt.figure()
plt.title('Balanced height vs non-balanced height')
plt.plot(pheight_not.t, pheight_not.data, label='not balanced', color='firebrick')
plt.plot(pheight_bal.t, pheight_bal.data, label='balanced', color='lime')
plt.legend()
plt.xlabel('time (s)')
plt.ylabel('perturbation height (m)')
plt.show()
